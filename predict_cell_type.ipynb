# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np



# define the network

class CellClassifier(nn.Module):
    """
    A neural network for cell type classification
    """
    def __init__(self, input_size, hidden_size, num_classes):
        """
        Initialize the model. Here, the model is a simple feedforward neural network with 2 hidden layers.
        
        Parameters:
            input_size (int): the number of input features
            hidden_size (int): the number of neurons in the hidden layer
            num_classes (int): the number of classes to predict
        """
        super(CellClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        """
        Forward pass of the neural network
        """
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        
        return F.log_softmax(x, dim=1)
    
def get_train_test_dataloaders(data, X=None, get_label_encoder=False):
    """
    Convert the data into PyTorch tensors and split into training and test sets. We then return the PyTorch dataloader objects.
    
    Parameters:
        data (polars Dataframe): the data to be used for training and testing
        X: Optional parameter if we want to directly specify the predictors. This is useful for when we are not using the X directly from 
        the dataset. For example X could be the embeddings from GAE
    """
    
    # define the data loader
    from torch.utils.data import TensorDataset, DataLoader
    from sklearn.preprocessing import LabelEncoder

    biomarkers = ['CD45', 'CD3', 'CD4', 'CD8', 'FOXP3', 'CD56', 'CD20', 'CD14', 'CD163', 'CD68', 
              'SOX10', 'S100B', 'KI67', 'CD25', 'PD1', 'LAG3', 'TIM3', 'CD27', 'PDL1', 'B7H3', 
              'IDO1', 'B2M', 'MHCI', 'MHCII', 'MRC1', 'TGM2']
    
    
    X = data[biomarkers].to_pandas().values if X is None else X

    # convert the biomarker data into PyTorch tensors
    X_tensor = torch.tensor(X, dtype=torch.float)


    # convert the cell type labels into integers
    label_encoder = LabelEncoder()
    cell_type_column = 'CLUSTER_LABEL' if 'CLUSTER_LABEL' in data.columns else 'celltype'
    y = label_encoder.fit_transform(data[cell_type_column].to_pandas())  # convert to pandas for label encoding

    # convert the labels into PyTorch tensors
    y_tensor = torch.tensor(y, dtype=torch.long)

    # Combine the tensors
    dataset = TensorDataset(X_tensor, y_tensor)



    # Temporarily switch default tensor type to CPU
    if torch.cuda.is_available():
        torch.set_default_tensor_type('torch.FloatTensor')

    # Split the data into training and test sets
    train_size = int(0.8 * len(dataset))  # 80% for training
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

    # Switch default tensor type back to CUDA
    if torch.cuda.is_available():
        torch.set_default_tensor_type('torch.cuda.FloatTensor')



    # Define your dataloaders
    batch_size = 32  # choose the batch size that suits your needs
    
    # Create a generator for the 'cuda' device
    g = torch.Generator(device)

    # Define your dataloaders with the 'cuda' generator
    train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, generator=g)
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, generator=g)

    # train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    # test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
    
    if get_label_encoder: return train_dataloader, test_dataloader, label_encoder
    
    else: return train_dataloader, test_dataloader
    
    
def train_model(model, train_dataloader, num_epochs=100, print_loss=True):
    """
    Train the model
    
    Parameters:
        model (nn.Module): the model to be trained
        train_dataloader (DataLoader): the dataloader for the training data
    """
    
    # Define the loss function
    loss_function = nn.NLLLoss()

    # Define the optimizer - Stochastic Gradient Descent
    optimizer = optim.SGD(model.parameters(), lr=0.01)

    # Training loop
    for epoch in range(num_epochs):  # number of epochs
        for inputs, targets in train_dataloader:
            inputs, targets = inputs.to(device), targets.to(device)        

            # Clear the gradients from the last step
            optimizer.zero_grad()

            # Forward pass
            outputs = model(inputs)

            # Compute the loss
            loss = loss_function(outputs, targets)

            # Backward pass and update
            loss.backward()
            optimizer.step()

        if print_loss:
            # Print the loss for this epoch
            if epoch % 10 == 0:  # Only print every 10 epochs
                print('Epoch', epoch, 'Loss', loss.item())
        
        
def test_model(model, test_dataloader, print_acc=True, return_acc=True, label_encoder=None):
    """
    Evaluate the model
    
    Parameters:
        model (nn.Module): the model to be evaluated
        test_dataloader (DataLoader): the dataloader for the test data
    """
    
    # switch the model to evaluation mode
    model.eval()

    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    # No need to track gradients for validation, saves memory and computations
    with torch.no_grad():
        for inputs, labels in test_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward pass
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = correct / total
    if print_acc: print('Test Accuracy: %.2f %%' % (100 * accuracy))
    
    if label_encoder:
        all_preds = label_encoder.inverse_transform(all_preds)
        all_labels = label_encoder.inverse_transform(all_labels)
        
    if return_acc: return all_labels, all_preds, accuracy
    
    else: return all_labels, all_preds

def test_model_thresholds(model, test_dataloader):
    """
    Evaluate the model
    
    Parameters:
        model (nn.Module): the model to be evaluated
        test_dataloader (DataLoader): the dataloader for the test data
    """
    
    # switch the model to evaluation mode
    model.eval()

    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    # No need to track gradients for validation, saves memory and computations
    with torch.no_grad():
        for inputs, labels in test_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward pass
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = correct / total
    # print('Test Accuracy: %.2f %%' % (100 * accuracy))
    
    return accuracy

# %% [markdown]
# ## Predicting Cell Type
#
# Here, as a first step, we will predict cell type in a supervised manner. We will treat the cell labels from the melanoma dataset as the ground truth and see how well the biomarkers are at predicting the cell type. In the next sections, we will work with clustering and using the biomarkers of neighboring cells as well

# %% [markdown]
# For the first part, we just try to predict the cell types for the first region (df_0_1_1), which is the first sample_id and first FOV_id. We use the biomarkers of the cells as the predictors for the cell type. The model that we are using here is a simple feedforward neural network with 2 hidden layers consisting of 50 neurons each. The input layer is all the biomarkers. We apply the softmax to the output layer, so we'll get probabilities for each of the classes. We take the class with the highest probability to be our predicted cell type. For this first region (df_0_1_1), we got an accuracy of around 89%. In the next stage, we also do this for the whole dataset

# %% [markdown]
# ### Train and test the model and create visualizations

# %%
# for the first data (df_0_1_1)

import pandas as pd
import polars as pl


cell_types = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_cell_types.csv")
expressions = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_expression.csv")

# join cell types and expression on CELL_ID

data = cell_types.join(expressions, on="CELL_ID")

# Define the model

input_size = 26
hidden_size = 50  # could be optimized
num_classes = len(data["CLUSTER_LABEL"].unique())

# create the model and transfer it to GPU if avilable
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
model = CellClassifier(input_size, hidden_size, num_classes).to(device)


from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
label_encoder.fit_transform(data['CLUSTER_LABEL'].to_pandas())  # convert to pandas for label encoding
class_names = label_encoder.classes_
class_names, len(class_names)
# Out:
# (array(['Adipo_Lang', 'B', 'MHCIIneg_macro', 'MHCIIpos_macro', 'NK',
#         'NKT4', 'NKT8', 'Nerve', 'Other_macro', 'T4_8', 'Tconv4', 'Tconv8',
#         'Tnull', 'Treg4', 'Tumor', 'Unknown'], dtype=object),
#  16)

# %%
# get the train and test dataloaders
train_dataloader, test_dataloader = get_train_test_dataloaders(data)

# Train the model
train_model(model, train_dataloader, num_epochs=200)

# Get the true and predicted labels
true_labels, predicted_labels = test_model(model, test_dataloader)

# Get unique classes in true and predicted labels
unique_classes = np.unique(np.concatenate((np.unique(true_labels), np.unique(predicted_labels))))

# Get the corresponding class names
unique_class_names = label_encoder.inverse_transform(unique_classes)

# Compute the confusion matrix
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_labels, predicted_labels, labels=unique_classes)

# Visualize the confusion matrix
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=unique_class_names, yticklabels=unique_class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 5
#       2 train_dataloader, test_dataloader = get_train_test_dataloaders(data)
#       4 # Train the model
# ----> 5 train_model(model, train_dataloader, num_epochs=200)
#       7 # Get the true and predicted labels
#       8 true_labels, predicted_labels = test_model(model, test_dataloader)
#
# Cell In[2], line 134, in train_model(model, train_dataloader, num_epochs, print_loss)
#     131 optimizer.zero_grad()
#     133 # Forward pass
# --> 134 outputs = model(inputs)
#     136 # Compute the loss
#     137 loss = loss_function(outputs, targets)
#
# File ~/python/envs/space-env3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[2], line 33, in CellClassifier.forward(self, x)
#      29 def forward(self, x):
#      30     """
#      31     Forward pass of the neural network
#      32     """
# ---> 33     x = F.relu(self.fc1(x))
#      34     x = F.relu(self.fc2(x))
#      35     x = self.fc3(x)
#
# File ~/python/envs/space-env3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/python/envs/space-env3/lib/python3.10/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (32x26 and 52x50)

# %% [markdown]
# ### Let's try after removing 'Unknown' type

# %%
# get unique cluster labels and their counts

cell_types_counts = data.groupby("CLUSTER_LABEL").count()

# remove 'Unknown' cluster label from the data

data_without_unknown = data.filter(pl.col("CLUSTER_LABEL") != "Unknown")

# %%
# Define the model

input_size = 26
hidden_size = 50  # could be optimized
num_classes = len(data_without_unknown["CLUSTER_LABEL"].unique())

# create the model and transfer it to GPU if avilable
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
model = CellClassifier(input_size, hidden_size, num_classes).to(device)

# get the train and test dataloaders
# train_dataloader, test_dataloader = get_train_test_dataloaders(data_without_unknown)

label_encoder = LabelEncoder()
label_encoder.fit_transform(data_without_unknown['CLUSTER_LABEL'].to_pandas())  # convert to pandas for label encoding
class_names = label_encoder.classes_
class_names, len(class_names)
# Out:
# (array(['Adipo_Lang', 'B', 'MHCIIneg_macro', 'MHCIIpos_macro', 'NK',
#         'NKT4', 'NKT8', 'Nerve', 'Other_macro', 'T4_8', 'Tconv4', 'Tconv8',
#         'Tnull', 'Treg4', 'Tumor'], dtype=object),
#  15)

# %%
# get the train and test dataloaders
train_dataloader, test_dataloader = get_train_test_dataloaders(data_without_unknown)

# Train the model
train_model(model, train_dataloader, num_epochs=200)

# Get the true and predicted labels
true_labels, predicted_labels = test_model(model, test_dataloader)

# Get unique classes in true and predicted labels
unique_classes = np.unique(np.concatenate((np.unique(true_labels), np.unique(predicted_labels))))

# Get the corresponding class names
unique_class_names = label_encoder.inverse_transform(unique_classes)

# Compute the confusion matrix
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_labels, predicted_labels, labels=unique_classes)

# Visualize the confusion matrix
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=unique_class_names, yticklabels=unique_class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Epoch 0 Loss 0.2559344172477722
# Epoch 10 Loss 0.7827830910682678
# Epoch 20 Loss 0.054736342281103134
# Epoch 30 Loss 0.3003692924976349
# Epoch 40 Loss 0.002129226690158248
# Epoch 50 Loss 0.08237877488136292
# Epoch 60 Loss 0.0024020455311983824
# Epoch 70 Loss 0.02376013807952404
# Epoch 80 Loss 0.0020463678520172834
# Epoch 90 Loss 0.004075548145920038
# Epoch 100 Loss 0.009032553061842918
# Epoch 110 Loss 0.18313054740428925
# Epoch 120 Loss 0.14431846141815186
# Epoch 130 Loss 0.004825884476304054
# Epoch 140 Loss 0.0006833203369751573
# Epoch 150 Loss 0.002683240221813321
# Epoch 160 Loss 0.09515073895454407
# Epoch 170 Loss 0.04947459325194359
# Epoch 180 Loss 0.005640579387545586
# Epoch 190 Loss 0.5121169090270996
# Test Accuracy: 94.19 %

# %%
import numpy as np

print("Unique true labels: ", np.unique(true_labels))
print("Unique predicted labels: ", np.unique(predicted_labels))
# Out:
# Unique true labels:  [ 0  1  2  3  5  8  9 10 11 13 14]
# Unique predicted labels:  [ 0  1  2  3  4  8  9 10 11 13 14]

# %%
missing_classes = label_encoder.inverse_transform([5,6,7,12])
print(missing_classes)
# Out:
# ['NKT4' 'NKT8' 'Nerve' 'Tnull']

# %% [markdown]
# ### Using K-fold cross validation

# %%
from sklearn.model_selection import KFold

def train_test_model_k_fold(dataset, input_size, hidden_size=50, num_classes=16, k=5, num_epochs=100, print_loss=True):
    """
    Train and test the model using K-Fold cross-validation
    
    Parameters:
        dataset (torch.utils.data.Dataset): the dataset for training and testing
        input_size (int): number of input features
        hidden_size (int): number of nodes in a hidden layer
        num_classes (int): number of classes (output dimension)
        k (int): the number of folds for cross-validation
        num_epochs (int): the number of epochs for training
        print_loss (bool): whether to print the loss during training
    """
    
    # Define the loss function
    loss_function = nn.NLLLoss()

    # Define K-Fold cross-validation
    kfold = KFold(n_splits=k, shuffle=True)

    accuracies = []

    # K-Fold cross-validation loop
    for fold, (train_ids, test_ids) in enumerate(kfold.split(dataset)):
         # create the model and transfer it to GPU if avilable
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        model = CellClassifier(input_size, hidden_size, num_classes).to(device)
        
        # Define the optimizer - Stochastic Gradient Descent
        optimizer = optim.SGD(model.parameters(), lr=0.01)
        
        
        print(f'FOLD {fold}')
        print('--------------------------------')

        # Define data loaders for training and testing data in this fold
        train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids)
        test_subsampler = torch.utils.data.SubsetRandomSampler(test_ids)

        train_loader = torch.utils.data.DataLoader(
                          dataset, 
                          batch_size=10, sampler=train_subsampler)
        test_loader = torch.utils.data.DataLoader(
                          dataset,
                          batch_size=10, sampler=test_subsampler)

        # Training loop
        model.train()
        for epoch in range(num_epochs):
            for inputs, targets in train_loader:
                inputs, targets = inputs.to(device), targets.to(device)        

                # Clear the gradients
                optimizer.zero_grad()

                # Forward pass
                outputs = model(inputs)

                # Compute the loss
                loss = loss_function(outputs, targets)

                # Backward pass and update
                loss.backward()
                optimizer.step()

            if print_loss:
                # Print the loss for this epoch
                if epoch % 10 == 0:  # Only print every 10 epochs
                    print('Epoch', epoch, 'Loss', loss.item())

        # Evaluation for this fold
        correct, total = 0, 0
        model.eval()

        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = model(inputs)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        accuracy = correct / total
        accuracies.append(accuracy)
        print(f'Accuracy for fold {fold}: {accuracy * 100}%')

    print('--------------------------------')
    print('FINAL RESULTS')
    print(f'Average accuracy across {k}-folds: {np.mean(accuracies) * 100}%')
    print('--------------------------------')

    return accuracies

# %%
import polars as pl


cell_types = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_cell_types.csv")
expressions = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_expression.csv")

# join cell types and expression on CELL_ID

data = cell_types.join(expressions, on="CELL_ID")

from sklearn.preprocessing import LabelEncoder
from torch.utils.data import TensorDataset

# List of biomarkers
biomarkers = ['CD45', 'CD3', 'CD4', 'CD8', 'FOXP3', 'CD56', 'CD20', 'CD14', 'CD163', 'CD68', 
              'SOX10', 'S100B', 'KI67', 'CD25', 'PD1', 'LAG3', 'TIM3', 'CD27', 'PDL1', 'B7H3', 
              'IDO1', 'B2M', 'MHCI', 'MHCII', 'MRC1', 'TGM2']

# Extract biomarker data and convert to tensor
X = data_without_unknown[biomarkers].to_pandas().values
X_tensor = torch.tensor(X, dtype=torch.float)

# Convert cell type labels into integers and then to tensor
label_encoder = LabelEncoder()
cell_type_column = 'CLUSTER_LABEL' if 'CLUSTER_LABEL' in data_without_unknown.columns else 'celltype'
y = label_encoder.fit_transform(data_without_unknown[cell_type_column].to_pandas())
y_tensor = torch.tensor(y, dtype=torch.long)


model = CellClassifier(input_size, hidden_size, num_classes).to(device)
dataset = TensorDataset(X_tensor, y_tensor)
accuracies = train_test_model_k_fold(dataset, input_size=26, hidden_size=50, num_classes=15, k=5, num_epochs=200)
# Out:
# FOLD 0
# --------------------------------
# Epoch 0 Loss 0.22503149509429932
# Epoch 10 Loss 0.15612636506557465
# Epoch 20 Loss 0.006797758862376213
# Epoch 30 Loss 0.05641729012131691
# Epoch 40 Loss 0.01518623623996973
# Epoch 50 Loss 0.20336897671222687
# Epoch 60 Loss 8.391105802729726e-05
# Epoch 70 Loss 0.10696584731340408
# Epoch 80 Loss 0.001397335552610457
# Epoch 90 Loss 0.247292160987854
# Epoch 100 Loss 0.0029157965909689665
# Epoch 110 Loss 0.002568470314145088
# Epoch 120 Loss 0.008840986527502537
# Epoch 130 Loss 0.03521523252129555
# Epoch 140 Loss 0.049086153507232666
# Epoch 150 Loss 0.004066826310008764
# Epoch 160 Loss 5.758856059401296e-05
# Epoch 170 Loss 0.01656331866979599
# Epoch 180 Loss 2.046417193923844e-06
# Epoch 190 Loss 0.0007665029261261225
# Accuracy for fold 0: 94.43757725587145%
# FOLD 1
# --------------------------------
# Epoch 0 Loss 0.2155313938856125
# Epoch 10 Loss 0.09443005919456482
# Epoch 20 Loss 0.3043608069419861
# Epoch 30 Loss 0.049135178327560425
# Epoch 40 Loss 0.683258593082428
# Epoch 50 Loss 0.014870385639369488
# Epoch 60 Loss 0.008348998613655567
# Epoch 70 Loss 0.16208197176456451
# Epoch 80 Loss 0.02810141257941723
# Epoch 90 Loss 0.10689634084701538
# Epoch 100 Loss 0.08778127282857895
# Epoch 110 Loss 0.015225566923618317
# Epoch 120 Loss 0.00035766357905231416
# Epoch 130 Loss 0.00717472517862916
# Epoch 140 Loss 0.027940377593040466
# Epoch 150 Loss 0.003978602588176727
# Epoch 160 Loss 0.002257297979667783
# Epoch 170 Loss 0.002643837593495846
# Epoch 180 Loss 0.0022433334961533546
# Epoch 190 Loss 0.024557940661907196
# Accuracy for fold 1: 95.17923362175526%
# FOLD 2
# --------------------------------
# Epoch 0 Loss 1.2470940351486206
# Epoch 10 Loss 0.11697748303413391
# Epoch 20 Loss 0.06709013134241104
# Epoch 30 Loss 0.01788594387471676
# Epoch 40 Loss 0.0072025116533041
# Epoch 50 Loss 0.3323119282722473
# Epoch 60 Loss 0.031915586441755295
# Epoch 70 Loss 0.014795646071434021
# Epoch 80 Loss 0.043724339455366135
# Epoch 90 Loss 0.20363785326480865
# Epoch 100 Loss 0.020424967631697655
# Epoch 110 Loss 0.04150153324007988
# Epoch 120 Loss 0.014690800569951534
# Epoch 130 Loss 0.0014082854613661766
# Epoch 140 Loss 0.05912281200289726
# Epoch 150 Loss 0.029985228553414345
# Epoch 160 Loss 0.002732168883085251
# Epoch 170 Loss 0.013802689500153065
# Epoch 180 Loss 0.023024601861834526
# Epoch 190 Loss 0.041477590799331665
# Accuracy for fold 2: 94.06674907292954%
# FOLD 3
# --------------------------------
# Epoch 0 Loss 0.9114508628845215
# Epoch 10 Loss 0.5626325011253357
# Epoch 20 Loss 0.06211031973361969
# Epoch 30 Loss 0.016240542754530907
# Epoch 40 Loss 0.003493649186566472
# Epoch 50 Loss 0.10539045184850693
# Epoch 60 Loss 0.013642951846122742
# Epoch 70 Loss 0.0002362467348575592
# Epoch 80 Loss 0.3544086515903473
# Epoch 90 Loss 0.38697174191474915
# Epoch 100 Loss 0.005078135523945093
# Epoch 110 Loss 0.015481947921216488
# Epoch 120 Loss 0.021877488121390343
# Epoch 130 Loss 0.049321215599775314
# Epoch 140 Loss 0.011843808926641941
# Epoch 150 Loss 0.07166658341884613
# Epoch 160 Loss 0.031943920999765396
# Epoch 170 Loss 0.029947444796562195
# Epoch 180 Loss 0.027131617069244385
# Epoch 190 Loss 0.0015158216701820493
# Accuracy for fold 3: 93.94313967861557%
# FOLD 4
# --------------------------------
# Epoch 0 Loss 0.47920310497283936
# Epoch 10 Loss 0.023280980065464973
# Epoch 20 Loss 0.05214376747608185
# Epoch 30 Loss 0.9625906348228455
# Epoch 40 Loss 0.04035957157611847
# Epoch 50 Loss 0.814042329788208
# Epoch 60 Loss 0.011200624518096447
# Epoch 70 Loss 0.10630682110786438
# Epoch 80 Loss 0.0034462895710021257
# Epoch 90 Loss 0.007529664784669876
# Epoch 100 Loss 0.0022740415297448635
# Epoch 110 Loss 0.03038799576461315
# Epoch 120 Loss 0.034782540053129196
# Epoch 130 Loss 0.0018272224115207791
# Epoch 140 Loss 0.04482613503932953
# Epoch 150 Loss 0.16070596873760223
# Epoch 160 Loss 0.001579057308845222
# Epoch 170 Loss 0.0061264969408512115
# Epoch 180 Loss 0.4088838994503021
# Epoch 190 Loss 0.0012271066661924124
# Accuracy for fold 4: 93.69592088998763%
# --------------------------------
# FINAL RESULTS
# Average accuracy across 5-folds: 94.26452410383189%
# --------------------------------

# %% [markdown]
# ### Using the entire dataset

# %% [markdown]
# Now that we have tried predicting the cell type (assuming we know the ground truth) for one of the regions, we will now predict the cell type using the biomarkers for the entire dataset.

# %%
# for the whole dataset (Melanoma_Final)

data_melanoma_final = pl.read_csv("/juno/work/shah/users/ibrahih3/melanoma/Melanoma_FINAL.csv")


# Define the model

input_size = 26
hidden_size = 50  # could be optimized
num_classes = len(data_melanoma_final["celltype"].unique())
    
# check if a GPU is available and if not, we will use a CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
model = CellClassifier(input_size, hidden_size, num_classes).to(device)

train_dataloader, test_dataloader = get_train_test_dataloaders(data_melanoma_final)

# Train the model
train_model(model, train_dataloader, num_epochs=100)

# Get the true and predicted labels
true_labels, predicted_labels = test_model(model, test_dataloader)

# Get unique classes in true and predicted labels
unique_classes = np.unique(np.concatenate((np.unique(true_labels), np.unique(predicted_labels))))

# Get the corresponding class names
unique_class_names = label_encoder.inverse_transform(unique_classes)

# Compute the confusion matrix
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_labels, predicted_labels, labels=unique_classes)

# Visualize the confusion matrix
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=unique_class_names, yticklabels=unique_class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Epoch 0 Loss 0.02918674424290657
# Epoch 10 Loss 0.10546977818012238
# Epoch 20 Loss 0.17210589349269867
# Epoch 30 Loss 0.1652706414461136
# Epoch 40 Loss 0.08003383129835129
# Epoch 50 Loss 0.015390589833259583
# Epoch 60 Loss 0.14332453906536102
# Epoch 70 Loss 0.3084774613380432
# Epoch 80 Loss 0.2874428331851959
# Epoch 90 Loss 0.06113237515091896
# Test Accuracy: 92.57 %
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 29
#      26 unique_classes = np.unique(np.concatenate((np.unique(true_labels), np.unique(predicted_labels))))
#      28 # Get the corresponding class names
# ---> 29 unique_class_names = label_encoder.inverse_transform(unique_classes)
#      31 # Compute the confusion matrix
#      32 from sklearn.metrics import confusion_matrix
#
# File ~/python/envs/space-env3/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:160, in LabelEncoder.inverse_transform(self, y)
#     158 diff = np.setdiff1d(y, np.arange(len(self.classes_)))
#     159 if len(diff):
# --> 160     raise ValueError("y contains previously unseen labels: %s" % str(diff))
#     161 y = np.asarray(y)
#     162 return self.classes_[y]
#
# ValueError: y contains previously unseen labels: [16 17 18 19 20]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have your data in a DataFrame called data and the column of cell types is named 'celltype'
cell_type_counts = data_melanoma_final['celltype'].value_counts()

plt.figure(figsize=(10,8))
plt.bar(cell_type_counts['celltype'], cell_type_counts['counts'])
plt.xlabel('Cell Type')
plt.ylabel('Count')
plt.title('Distribution of Cell Types')
plt.xticks(rotation=90)
plt.show()
# plt.bar(cell_type_counts['celltype'], cell_type_counts['counts'])
# plt.xticks(rotation=90)
# plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_confusion_matrix(true_labels, predicted_labels, classes):
    """
    Plots a confusion matrix using seaborn.

    Parameters:
        true_labels (list): List of true labels
        predicted_labels (list): List of predicted labels by the model
        classes (list): List of class names
    """

    # Compute confusion matrix and normalize it
    cm = confusion_matrix(true_labels, predicted_labels, normalize='true')
    cm_df = pd.DataFrame(cm, index=classes, columns=classes)

    # Plot the heatmap
    plt.figure(figsize=(15, 10))
    sns.heatmap(cm_df, annot=True, fmt=".2f", annot_kws={"size": 10}, cmap='YlGnBu')
    plt.title("Confusion Matrix")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# Assuming you have the LabelEncoder object and class_names
label_encoder = LabelEncoder()
label_encoder.fit(data_melanoma_final['celltype'].to_pandas())

true_class_names = label_encoder.inverse_transform(true_labels)
predicted_class_names = label_encoder.inverse_transform(predicted_labels)

# You can get your class names from the LabelEncoder
class_names = label_encoder.classes_

# Plot the confusion matrix
plot_confusion_matrix(true_class_names, predicted_class_names, class_names)

# %%
# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(h.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()

# %% [markdown]
# ### Probabilistic Approach (needs some work)
#
# Here, we are still assuming that we know the ground truth of the cell types and we'll try to predict them using the biomarkers. But unlike in the previous step, we take a probabilistic approach here. That means our neural network for predicting the cell types is probabilistic. Instead of learning a single value for the weights and biases of the network, we'll instead learn a distribution over these parameters. Then when we do the forward pass for predicting, we'll sample from the learned distribution and use that in our forward pass to make predictions.

# %%
import pyro
import pyro.distributions as dist
from pyro.nn import PyroModule, PyroSample
import torch.nn.functional as F


class BayesianCellClassifier(PyroModule):
    def __init__(self, input_size, hidden_size, num_classes):
        super(BayesianCellClassifier, self).__init__()
        self.fc1 = PyroModule[nn.Linear](input_size, hidden_size)
        self.fc1.weight = PyroSample(dist.Normal(0., 1.).expand([hidden_size, input_size]).to_event(2))
        self.fc1.bias = PyroSample(dist.Normal(0., 10.).expand([hidden_size]).to_event(1))
        
        self.fc2 = PyroModule[nn.Linear](hidden_size, hidden_size)
        self.fc2.weight = PyroSample(dist.Normal(0., 1.).expand([hidden_size, hidden_size]).to_event(2))
        self.fc2.bias = PyroSample(dist.Normal(0., 10.).expand([hidden_size]).to_event(1))
        
        self.fc3 = PyroModule[nn.Linear](hidden_size, num_classes)
        self.fc3.weight = PyroSample(dist.Normal(0., 1.).expand([num_classes, hidden_size]).to_event(2))
        self.fc3.bias = PyroSample(dist.Normal(0., 10.).expand([num_classes]).to_event(1))

    def forward(self, x, y=None):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        
        with pyro.plate("data", x.shape[0]):
            obs = pyro.sample("obs", dist.Categorical(logits=x), obs=y)
        return x

from pyro.infer import SVI, Trace_ELBO
from pyro.optim import Adam

def train(model, train_loader, num_epochs=100):
    guide = AutoDiagonalNormal(model)  # you can try other types of guides

    optim = Adam({"lr": 0.01})
    svi = SVI(model, guide, optim, loss=Trace_ELBO())

    model.train()
    for epoch in range(num_epochs):
        epoch_loss = 0
        for x, y in train_loader:
            epoch_loss += svi.step(x, y)

        print(f"Epoch {epoch}: Loss {epoch_loss / len(train_loader)}")

def test(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for x, y in test_loader:
            output = model(x)
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(y.view_as(pred)).sum().item()
            total += y.shape[0]
    print(f"Accuracy: {correct / total}")

# %%
if torch.cuda.is_available():
    torch.set_default_tensor_type('torch.cuda.FloatTensor')

# %%
import pyro
import pyro.distributions as dist
from pyro.nn import PyroModule, PyroSample
import torch.nn.functional as F

class BayesianNet(PyroModule):
    def __init__(self, input_size, hidden_size, num_classes):
        super().__init__()
        self.fc1 = PyroModule[nn.Linear](input_size, hidden_size)
        self.fc1.weight = PyroSample(dist.Normal(0., 10.).expand([hidden_size, input_size]).to_event(2))
        self.fc1.bias = PyroSample(dist.Normal(0., 10.).expand([hidden_size]).to_event(1))
        self.fc2 = PyroModule[nn.Linear](hidden_size, hidden_size)
        self.fc2.weight = PyroSample(dist.Normal(0., 10.).expand([hidden_size, hidden_size]).to_event(2))
        self.fc2.bias = PyroSample(dist.Normal(0., 10.).expand([hidden_size]).to_event(1))
        self.fc3 = PyroModule[nn.Linear](hidden_size, num_classes)
        self.fc3.weight = PyroSample(dist.Normal(0., 10.).expand([num_classes, hidden_size]).to_event(2))
        self.fc3.bias = PyroSample(dist.Normal(0., 10.).expand([num_classes]).to_event(1))

    def forward(self, x, y=None):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        with pyro.plate("data", x.shape[0]):
            obs = pyro.sample("obs", dist.Categorical(logits=x), obs=y)
        return x
    
from pyro.infer.autoguide import AutoDiagonalNormal, AutoMultivariateNormal

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define your model
model = BayesianNet(input_size=26, hidden_size=50, num_classes=16).to(device)

train_dataloader, test_dataloader = get_train_test_dataloaders(data)

# Define the guide function
guide = AutoDiagonalNormal(model)
guide.to(device)  # move the guide to the device

# Define the optimizer
optimizer = pyro.optim.Adam({"lr": 0.01})

from pyro.infer import SVI, Trace_ELBO

# Define the inference algorithm
svi = SVI(model, guide, optimizer, loss=Trace_ELBO())


# Training loop
num_epochs = 200
for epoch in range(num_epochs):
    epoch_loss = 0
    for inputs, targets in train_dataloader:
        # Move inputs and targets to device
        inputs, targets = inputs.to(device), targets.to(device)
        # Perform a step of SVI (this will update the parameters of the model and guide)
        loss = svi.step(inputs, targets)
        epoch_loss += loss
    # Print the loss for this epoch
    print(f'Epoch {epoch+1}, Loss {epoch_loss/len(train_dataloader)}')


# Testing loop
model.eval()  # put the model in evaluation mode
total = 0
correct = 0

with torch.no_grad():  # deactivate autograd engine to reduce memory usage and speed up computations
    for inputs, targets in test_dataloader:
        # Move inputs and targets to device
        inputs, targets = inputs.to(device), targets.to(device)

        # Run the model on the inputs
        outputs = model(inputs)

        # Get the most probable class
        _, predicted = torch.max(outputs, 1)

        # Update total and correct counts
        total += targets.size(0)
        correct += (predicted == targets).sum().item()

print(f'Test Accuracy: {100 * correct / total}%')
# Out:
# Epoch 1, Loss 1153577.3693122228
# Epoch 2, Loss 140522.5673455556
# Epoch 3, Loss 93143.27255147298
# Epoch 4, Loss 73075.84564317067
# Epoch 5, Loss 63809.921775531766
# Epoch 6, Loss 57417.603322410585
# Epoch 7, Loss 50666.00684041977
# Epoch 8, Loss 46824.4776913325
# Epoch 9, Loss 42494.26808493932
# Epoch 10, Loss 39669.84567184448
# Epoch 11, Loss 37670.689437770845
# Epoch 12, Loss 35767.187468338016
# Epoch 13, Loss 33995.10182091395
# Epoch 14, Loss 32601.17446378072
# Epoch 15, Loss 30736.428320821127
# Epoch 16, Loss 30411.370194180807
# Epoch 17, Loss 28861.901361497243
# Epoch 18, Loss 27319.07685699463
# Epoch 19, Loss 27599.046328512828
# Epoch 20, Loss 26752.82081906001
# Epoch 21, Loss 24931.98609345754
# Epoch 22, Loss 25718.438328838347
# Epoch 23, Loss 23674.41607729594
# Epoch 24, Loss 23781.88521531423
# Epoch 25, Loss 23683.860171254477
# Epoch 26, Loss 22579.92921295166
# Epoch 27, Loss 22602.605617491405
# Epoch 28, Loss 22509.669765059152
# Epoch 29, Loss 22377.997239557903
# Epoch 30, Loss 21242.38937562307
# Epoch 31, Loss 20428.548871390023
# Epoch 32, Loss 21077.39309832255
# Epoch 33, Loss 20846.00263929367
# Epoch 34, Loss 19681.79118725459
# Epoch 35, Loss 19922.368195215862
# Epoch 36, Loss 20003.87500960032
# Epoch 37, Loss 19735.55006122589
# Epoch 38, Loss 19324.782806110383
# Epoch 39, Loss 18690.4916680336
# Epoch 40, Loss 18590.800104490914
# Epoch 41, Loss 17986.488452243804
# Epoch 42, Loss 18230.50567712784
# Epoch 43, Loss 18184.043332958223
# Epoch 44, Loss 18074.112187862396
# Epoch 45, Loss 17652.25964085261
# Epoch 46, Loss 17422.34922428131
# Epoch 47, Loss 17142.368865680695
# Epoch 48, Loss 16743.10245774587
# Epoch 49, Loss 16875.363009357454
# Epoch 50, Loss 17235.470228799186
# Epoch 51, Loss 16302.042481358845
# Epoch 52, Loss 15793.55413128535
# Epoch 53, Loss 16285.452036126455
# Epoch 54, Loss 17292.604053338368
# Epoch 55, Loss 16607.182343037923
# Epoch 56, Loss 16060.845493221283
# Epoch 57, Loss 15749.992746575674
# Epoch 58, Loss 16057.67096188863
# Epoch 59, Loss 16452.159158325194
# Epoch 60, Loss 15472.180301253002
# Epoch 61, Loss 15702.49762283961
# Epoch 62, Loss 14783.015163644155
# Epoch 63, Loss 15352.249435869853
# Epoch 64, Loss 15307.116364479065
# Epoch 65, Loss 14762.273757966359
# Epoch 66, Loss 15078.272451368968
# Epoch 67, Loss 14722.006344636282
# Epoch 68, Loss 16474.35659907659
# Epoch 69, Loss 14467.377671146392
# Epoch 70, Loss 14172.085152689617
# Epoch 71, Loss 15822.150618902842
# Epoch 72, Loss 14838.07091554006
# Epoch 73, Loss 14315.635170936584
# Epoch 74, Loss 14120.708929602306
# Epoch 75, Loss 14412.97045768102
# Epoch 76, Loss 14496.308325258891
# Epoch 77, Loss 13521.355718421935
# Epoch 78, Loss 13799.077990277608
# Epoch 79, Loss 13723.206596724192
# Epoch 80, Loss 13605.973150698344
# Epoch 81, Loss 13540.745170338949
# Epoch 82, Loss 13467.150274976095
# Epoch 83, Loss 13165.254646396637
# Epoch 84, Loss 13564.894597244263
# Epoch 85, Loss 12791.070733420054
# Epoch 86, Loss 12914.702762031555
# Epoch 87, Loss 13168.446808592478
# Epoch 88, Loss 13256.005604426065
# Epoch 89, Loss 12875.644049358369
# Epoch 90, Loss 13351.475113709768
# Epoch 91, Loss 13273.41939462026
# Epoch 92, Loss 12470.734321626027
# Epoch 93, Loss 12772.841479651133
# Epoch 94, Loss 13258.663393974304
# Epoch 95, Loss 12549.667929617564
# Epoch 96, Loss 12405.963852405548
# Epoch 97, Loss 12413.587202135723
# Epoch 98, Loss 12445.59299103419
# Epoch 99, Loss 11937.69303820928
# Epoch 100, Loss 12211.277773284912
# Test Accuracy: 2.5078369905956115%

# %%
import matplotlib.pyplot as plt

# we'll select the first 5 inputs in our test set
inputs, targets = next(iter(test_dataloader))
inputs = inputs[20:25]#.to(device)
targets = targets[20:25]

# Forward pass through deterministic neural network
model_deterministic = CellClassifier(26,50,16)
model_deterministic.eval()  # make sure the model is in eval mode
with torch.no_grad():
    outputs_det = torch.exp(model_deterministic(inputs))  # we use exp because our model uses log_softmax

# Forward pass through Bayesian neural network
model_bayesian = BayesianNet(input_size=26, hidden_size=50, num_classes=16)
model_bayesian.eval()
with torch.no_grad():
    # draw 100 samples
    outputs_bayesian_samples = [model_bayesian(inputs) for _ in range(100)]
    # convert list of tensors into tensor
    outputs_bayesian_samples = torch.stack(outputs_bayesian_samples)

# Predicted labels
predicted_labels_det = outputs_det.argmax(dim=1)
predicted_labels_bayesian = outputs_bayesian_samples.mean(0).argmax(dim=1)

# Plot the predictions
for i in range(5):  # for each of the 5 inputs
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.bar(range(16), outputs_det[i].cpu().numpy())
    plt.ylim([0, 1])
    plt.title(f"Input {i+1} - Deterministic Network\nTrue label: {targets[i].item()}, Predicted label: {predicted_labels_det[i].item()}")
    plt.xlabel("Class")
    plt.ylabel("Predicted probability")

    plt.subplot(1, 2, 2)
    # Calculate the mean softmax over the Bayesian samples to get an expected probability
    softmax_samples = torch.softmax(outputs_bayesian_samples, dim=-1)
    outputs_bayesian_mean = softmax_samples.mean(dim=0)
    plt.bar(range(16), outputs_bayesian_mean[i].cpu().numpy())
    plt.ylim([0, 1])
    plt.title(f"Input {i+1} - Bayesian Network\nTrue label: {targets[i].item()}, Predicted label: {predicted_labels_bayesian[i].item()}")
    plt.xlabel("Class")
    plt.ylabel("Predicted probability")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Clustering methods
#
# In this phase, we will now assume that we don't know the cell types and we will use clustering methods

# %% [markdown]
# In the first part, we use TSNE to reduce the dimensions of our biomarkers from 26 to 2 help us visualize the biomarker space in 2D. We the project the already labeled cells onto the 2D plane to see how well they cluster. We do see that the labeled cell types do indeed form a cluster, but we can't really say with full confidence that the labeled datset is right or wrong

# %%
# to see how the labels are clustered, here we use t-SNE to reduce the dimension to components and overlay it with the 16 labeled components

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# let's assume X is your 26-dimensional input data
X = data[biomarkers].to_pandas().values  # convert to pandas for .values

# Apply t-SNE to X
tsne = TSNE(n_components=2, random_state=0)  # set n_components to 2 for a 2D visualization
X_tsne = tsne.fit_transform(X)

# Plot the result
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis')  # color points by their true labels (if available)
plt.colorbar()
plt.title('t-SNE visualization of cell types')
plt.xlabel('t-SNE dimension 1')
plt.ylabel('t-SNE dimension 2')
plt.show()

# %% [markdown]
# If we don't use any labels, then we'd see the following clusters. It's not really distinctive in that we clearly see how many clusters there are, so we can't tell for sure how many cell types there really are

# %%
# without using any labels

plt.scatter(X_tsne[:, 0], X_tsne[:, 1])
plt.title('t-SNE visualization of cell data')
plt.xlabel('t-SNE dimension 1')
plt.ylabel('t-SNE dimension 2')
plt.show()

# %% [markdown]
# If we then use the t-SNE data (the data whose dimension is reduced from 26 to 2) and use k means clustering by specifying the value for k, we'd get the following. I tried this for different values of k, and the clusters change a bit, but for the main part, we do see that there are clusters. We just can't conclusively say how many

# %%
# using k means clustering on the t-SNE transformed data and choosing 16 clusters

from sklearn.cluster import KMeans

# Apply K-means to the 2D t-SNE data
kmeans = KMeans(n_clusters=16, random_state=0)  # choose the number of clusters
cluster_labels = kmeans.fit_predict(X_tsne)

# Plot the t-SNE data, colored by K-means cluster labels
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=cluster_labels, cmap='viridis')
plt.colorbar()
plt.title('t-SNE visualization of cell data, colored by K-means clusters')
plt.xlabel('t-SNE dimension 1')
plt.ylabel('t-SNE dimension 2')
plt.show()
# Out:
# /home/ibrahih3/python/envs/space-env2/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Here, instead of applying k means clustering on the t-SNE data, I applied to to the original data with 26 dimensions to see if the clusters would change, but they remain mostly similar with the previous method

# %%
# k means on the original data and choosing 16 clusters

from sklearn.cluster import KMeans

# Apply K-means to the original data
kmeans = KMeans(n_clusters=16, random_state=0)  # choose the number of clusters
cluster_labels = kmeans.fit_predict(X)

# Apply t-SNE to the original data
tsne = TSNE(n_components=2, random_state=0)
X_tsne = tsne.fit_transform(X)

# Plot the t-SNE data, colored by K-means cluster labels
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=cluster_labels, cmap='viridis')
plt.colorbar()
plt.title('t-SNE visualization of cell data, colored by K-means clusters')
plt.xlabel('t-SNE dimension 1')
plt.ylabel('t-SNE dimension 2')
plt.show()
# Out:
# /home/ibrahih3/python/envs/space-env2/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ### Cell type prediction using biomarkers of neighbors as well

# %% [markdown]
# Next, I'll use the biomarkers of the neighboring cells in addition to the cell itself. We'll use multiple methods for this. We'll use simple concatanation of neighbor biomarkers using different methods of aggregation. We'll also use a GAE to get a representation that takes into account neighborhood information as well. This will also allow us how far away we want to look. If we have a single layer, it'll only look to its immediate neighbors' biomarkers to get its embedding

# %% [markdown]
# To get biomarker information from the neighbors of the cells, we need to create the graph. Here, I calculate the distance between each cell and use a threshold to determine which cells should be neighbors

# %%
# data_melanoma_final = pl.read_csv("/juno/work/shah/users/ibrahih3/melanoma/Melanoma_FINAL.csv")
data_melanoma_final.head()

classes = data_melanoma_final['celltype'].unique()
# classes

# %%
import numpy as np
import pandas as pd
import polars as pl
from scipy.spatial import distance_matrix
import networkx as nx
import torch_geometric.utils as utils

# Read in the data
coordinates_with_id = pd.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_coords.csv")
expressions_with_id = pd.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_expression.csv")

coordinates = coordinates_with_id[['X', 'Y']]
# biomarkers = expressions_with_id.columns[2:]

def create_graph_from_coordinates(coordinates_df, threshold, expressions_df):
    """
    Create a graph from the coordinates of the cells.
    
    Args:
        coordinates_df (pd.DataFrame): A DataFrame with the columns 'X' and 'Y'.
        threshold (int): The distance threshold for two cells to be connected.
        expressions_df (pd.DataFrame): A DataFrame containing the columns ACQUISITION_ID, CELL_ID, and the biomarkers.
        
    Returns:
        nx.Graph: A graph with the cells as nodes and edges between cells that are within the distance threshold.
    """
    # Compute the distance matrix
    dist_matrix = distance_matrix(coordinates_df.values, coordinates_df.values)
    
    # Create an adjacency matrix based on the distance threshold
    adjacency_matrix = (dist_matrix < threshold).astype(int)
    
    # Remove self-loops by setting the diagonal to zero
    # np.fill_diagonal(adjacency_matrix, 0)
    
    # Convert adjacency matrix to DataFrame
    adjacency_df = pd.DataFrame(adjacency_matrix, index=coordinates_df.index, columns=coordinates_df.index)
    
    # Create a graph from the adjacency matrix
    graph = nx.from_pandas_adjacency(adjacency_df)
    
    biomarkers = ['CD45', 'CD3', 'CD4', 'CD8', 'FOXP3', 'CD56', 'CD20', 'CD14', 'CD163', 'CD68', 
              'SOX10', 'S100B', 'KI67', 'CD25', 'PD1', 'LAG3', 'TIM3', 'CD27', 'PDL1', 'B7H3', 
              'IDO1', 'B2M', 'MHCI', 'MHCII', 'MRC1', 'TGM2']
    
    # Add node features for each cell (node)
    for node in graph.nodes:
        graph.nodes[node]['features'] = expressions_df.loc[node, biomarkers].values
    
    return graph

# graph = create_graph_from_coordinates(coordinates, 30, expressions_with_id)

# %%
import matplotlib.pyplot as plt

plt.hist(coordinates_with_id['X'])
plt.show()
# Out:
#                CELL_ID         X        Y
# 0     000833cf8d5424a3  1491.077 -554.942
# 1     002287d8a57a5200   799.890 -635.517
# 2     00295b12f4ecf52c   683.569 -815.126
# 3     0030dccd41cea232   743.927 -826.846
# 4     003e872c6378b64d  1436.872 -507.476
# ...                ...       ...      ...
# 4778  ffd09d368e8875c4  1302.678 -934.377
# 4779  ffd53d1c5a8557e0   368.887 -225.610
# 4780  ffd7349c499c603c   660.715 -711.990
# 4781  fffb80be576ffb89   488.431 -653.683
# 4782  fffc03f9aa94464d  1312.347 -159.392
#
# [4783 rows x 3 columns]

# %%
path = "/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma"

response_label = pd.read_csv(f'{path}_label/graph_label.csv')
# create a dictionary from the response label dataframe, where the key is the region id and the value is the label

response_label_dict = {}

for i in range(len(response_label)):
    response_label_dict[response_label['REGION_ID'][i]] = response_label['RESPONSE_ABBREV'][i]

region_ids = list(response_label_dict.keys())
len(region_ids)
# Out:
# 315

# %%
cell_types = pl.read_csv(f"/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_1_2_8_cell_types.csv")
coordinates_with_id = pd.read_csv(f"/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_1_2_8_coords.csv")
expressions_with_id = pd.read_csv(f"/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_1_2_8_expression.csv")
expressions = pl.read_csv(f"/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_1_2_8_expression.csv")

coordinates = coordinates_with_id[['X', 'Y']]

data = cell_types.join(expressions, on="CELL_ID")
# Out:
# {'Treg8'}

# %%
path = "/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma"

all_true = []
all_pred = []
all_accuracies = []

from tqdm import tqdm

for region in tqdm(region_ids):
    cell_types = pl.read_csv(f"/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/{region}_cell_types.csv")
    coordinates_with_id = pd.read_csv(f"/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/{region}_coords.csv")
    expressions_with_id = pd.read_csv(f"/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/{region}_expression.csv")
    expressions = pl.read_csv(f"/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/{region}_expression.csv")
    
    coordinates = coordinates_with_id[['X', 'Y']]
    
    data = cell_types.join(expressions, on="CELL_ID")

    graph = create_graph_from_coordinates(coordinates, 30, expressions_with_id)
    
    G = utils.from_networkx(graph)

    # Convert list of features to a PyTorch tensor
    G.features = np.array(G.features).astype(float)
    features_tensor = torch.tensor(G.features, dtype=torch.float)

    # Add the features tensor to the Data object as the 'x' attribute
    G.x = features_tensor

    # get the new embeddings

    new_embeddings_mean = get_new_embedding(G, graph, aggr='mean')
    
    # Define the model

    input_size = 52  # 26 from the cell itself and 26 aggregated from the neighbors
    hidden_size = 50 # could be optimized
    num_classes = len(data['CLUSTER_LABEL'].unique()) # for each graph, we can have different number of cell types, so we generate it dynamically

    # create the model and transfer it to GPU if avilable
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # model = CellClassifier(input_size, hidden_size, num_classes).to(device)
    
    # get the train and test dataloaders for the embeddings using mean
    model = CellClassifier(input_size, hidden_size, num_classes).to(device)
    train_dataloader, test_dataloader, label_encoder = get_train_test_dataloaders(data, new_embeddings_mean, get_label_encoder=True) # Here, X is the embeddings we got from concatenation using mean aggregation

    train_model(model, train_dataloader, num_epochs=100, print_loss=False)
    labels, preds, acc = test_model(model, test_dataloader, print_acc=False, return_acc=True, label_encoder=label_encoder)
    
    all_true.extend(labels)
    all_pred.extend(preds)
    all_accuracies.append(acc)
# Out:
#   0%|          | 0/315 [00:00<?, ?it/s]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   0%|          | 1/315 [00:24<2:09:38, 24.77s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   1%|          | 2/315 [00:48<2:06:37, 24.27s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   1%|          | 3/315 [01:21<2:26:27, 28.16s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   1%|▏         | 4/315 [02:17<3:22:15, 39.02s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   2%|▏         | 5/315 [02:22<2:18:56, 26.89s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   2%|▏         | 6/315 [03:10<2:54:55, 33.96s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   2%|▏         | 7/315 [03:52<3:09:03, 36.83s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   3%|▎         | 8/315 [04:13<2:42:38, 31.79s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   3%|▎         | 9/315 [04:48<2:46:55, 32.73s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   3%|▎         | 10/315 [04:57<2:08:40, 25.31s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   3%|▎         | 11/315 [05:44<2:41:54, 31.95s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   4%|▍         | 12/315 [06:14<2:37:59, 31.29s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   4%|▍         | 13/315 [06:49<2:43:32, 32.49s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   4%|▍         | 14/315 [07:42<3:13:44, 38.62s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   5%|▍         | 15/315 [08:01<2:43:23, 32.68s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   5%|▌         | 16/315 [08:17<2:18:06, 27.71s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   5%|▌         | 17/315 [08:38<2:08:18, 25.84s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   6%|▌         | 18/315 [09:12<2:20:11, 28.32s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   6%|▌         | 19/315 [09:52<2:36:28, 31.72s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   6%|▋         | 20/315 [10:27<2:40:04, 32.56s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   7%|▋         | 21/315 [11:21<3:12:07, 39.21s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   7%|▋         | 22/315 [11:56<3:04:29, 37.78s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   7%|▋         | 23/315 [12:48<3:24:34, 42.03s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   8%|▊         | 24/315 [13:47<3:48:51, 47.19s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   8%|▊         | 25/315 [14:04<3:04:42, 38.22s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   8%|▊         | 26/315 [14:21<2:33:16, 31.82s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   9%|▊         | 27/315 [14:45<2:21:44, 29.53s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   9%|▉         | 28/315 [15:12<2:17:09, 28.67s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   9%|▉         | 29/315 [16:06<2:53:02, 36.30s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  10%|▉         | 30/315 [16:31<2:35:36, 32.76s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  10%|▉         | 31/315 [17:08<2:41:14, 34.07s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  10%|█         | 32/315 [17:57<3:02:12, 38.63s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  10%|█         | 33/315 [18:27<2:49:22, 36.04s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  11%|█         | 34/315 [18:59<2:43:35, 34.93s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  11%|█         | 35/315 [19:44<2:56:58, 37.92s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  11%|█▏        | 36/315 [20:19<2:52:20, 37.06s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  12%|█▏        | 37/315 [21:04<3:02:42, 39.43s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  12%|█▏        | 38/315 [22:02<3:27:37, 44.97s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  12%|█▏        | 39/315 [22:35<3:10:42, 41.46s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  13%|█▎        | 40/315 [22:51<2:34:32, 33.72s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  13%|█▎        | 41/315 [23:36<2:49:29, 37.11s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  13%|█▎        | 42/315 [24:09<2:42:45, 35.77s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  14%|█▎        | 43/315 [24:53<2:53:41, 38.31s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  14%|█▍        | 44/315 [25:21<2:39:33, 35.33s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  14%|█▍        | 45/315 [26:04<2:49:34, 37.68s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  15%|█▍        | 46/315 [26:38<2:42:59, 36.36s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  15%|█▍        | 47/315 [27:01<2:24:39, 32.39s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  15%|█▌        | 48/315 [27:31<2:21:31, 31.80s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  16%|█▌        | 49/315 [28:03<2:20:49, 31.76s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  16%|█▌        | 50/315 [28:34<2:19:32, 31.60s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  16%|█▌        | 51/315 [29:17<2:33:26, 34.87s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  17%|█▋        | 52/315 [29:38<2:14:41, 30.73s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  17%|█▋        | 53/315 [30:07<2:11:42, 30.16s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  17%|█▋        | 54/315 [30:34<2:07:35, 29.33s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  17%|█▋        | 55/315 [31:32<2:44:43, 38.02s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  18%|█▊        | 56/315 [32:02<2:33:03, 35.46s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  18%|█▊        | 57/315 [32:25<2:16:07, 31.66s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  18%|█▊        | 58/315 [33:15<2:39:26, 37.23s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  19%|█▊        | 59/315 [33:40<2:22:49, 33.48s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  19%|█▉        | 60/315 [34:22<2:33:59, 36.23s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  19%|█▉        | 61/315 [34:50<2:23:10, 33.82s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  20%|█▉        | 62/315 [35:32<2:32:08, 36.08s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  20%|██        | 63/315 [35:56<2:16:46, 32.56s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  20%|██        | 64/315 [36:23<2:08:31, 30.72s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  21%|██        | 65/315 [36:51<2:04:36, 29.91s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  21%|██        | 66/315 [37:23<2:07:51, 30.81s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  21%|██▏       | 67/315 [37:49<2:00:31, 29.16s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  22%|██▏       | 68/315 [38:24<2:07:53, 31.07s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  22%|██▏       | 69/315 [39:09<2:24:01, 35.13s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  22%|██▏       | 70/315 [39:46<2:26:01, 35.76s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  23%|██▎       | 71/315 [40:29<2:34:39, 38.03s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  23%|██▎       | 72/315 [40:54<2:17:47, 34.02s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  23%|██▎       | 73/315 [41:15<2:00:46, 29.95s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  23%|██▎       | 74/315 [41:49<2:05:20, 31.21s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  24%|██▍       | 75/315 [42:07<1:49:53, 27.47s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  24%|██▍       | 76/315 [42:26<1:38:52, 24.82s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  24%|██▍       | 77/315 [42:50<1:37:21, 24.55s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  25%|██▍       | 78/315 [43:28<1:53:04, 28.62s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  25%|██▌       | 79/315 [44:06<2:03:02, 31.28s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  25%|██▌       | 80/315 [44:23<1:46:35, 27.22s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  26%|██▌       | 81/315 [45:05<2:03:13, 31.60s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  26%|██▌       | 82/315 [45:53<2:21:24, 36.42s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  26%|██▋       | 83/315 [46:19<2:08:58, 33.35s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  27%|██▋       | 84/315 [46:58<2:15:17, 35.14s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  27%|██▋       | 85/315 [47:25<2:04:51, 32.57s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  27%|██▋       | 86/315 [47:59<2:06:13, 33.07s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  28%|██▊       | 87/315 [48:36<2:09:38, 34.11s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  28%|██▊       | 88/315 [49:05<2:03:35, 32.67s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  28%|██▊       | 89/315 [49:52<2:19:23, 37.00s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  29%|██▊       | 90/315 [50:14<2:02:10, 32.58s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  29%|██▉       | 91/315 [50:50<2:05:16, 33.56s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  29%|██▉       | 92/315 [51:13<1:53:15, 30.47s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  30%|██▉       | 93/315 [51:58<2:08:05, 34.62s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  30%|██▉       | 94/315 [52:26<2:00:56, 32.84s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  30%|███       | 95/315 [53:12<2:14:04, 36.56s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  30%|███       | 96/315 [53:32<1:56:11, 31.83s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  31%|███       | 97/315 [53:48<1:37:57, 26.96s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  31%|███       | 98/315 [54:03<1:24:01, 23.23s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  31%|███▏      | 99/315 [54:30<1:28:12, 24.50s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  32%|███▏      | 100/315 [55:15<1:49:35, 30.58s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  32%|███▏      | 101/315 [55:49<1:52:38, 31.58s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  32%|███▏      | 102/315 [56:44<2:17:03, 38.61s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  33%|███▎      | 103/315 [57:22<2:15:40, 38.40s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  33%|███▎      | 104/315 [57:43<1:56:59, 33.27s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  33%|███▎      | 105/315 [58:07<1:47:12, 30.63s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  34%|███▎      | 106/315 [58:45<1:53:34, 32.61s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  34%|███▍      | 107/315 [59:21<1:56:49, 33.70s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  34%|███▍      | 108/315 [1:00:09<2:11:27, 38.10s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  35%|███▍      | 109/315 [1:00:51<2:14:50, 39.28s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  35%|███▍      | 110/315 [1:01:21<2:04:47, 36.52s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  35%|███▌      | 111/315 [1:02:09<2:15:42, 39.91s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  36%|███▌      | 112/315 [1:02:43<2:08:49, 38.07s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  36%|███▌      | 113/315 [1:03:08<1:54:54, 34.13s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  36%|███▌      | 114/315 [1:03:23<1:34:45, 28.28s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  37%|███▋      | 115/315 [1:03:42<1:25:32, 25.66s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  37%|███▋      | 116/315 [1:04:11<1:28:13, 26.60s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  37%|███▋      | 117/315 [1:04:38<1:28:23, 26.78s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  37%|███▋      | 118/315 [1:05:29<1:51:16, 33.89s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  38%|███▊      | 119/315 [1:05:55<1:42:59, 31.53s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  38%|███▊      | 120/315 [1:06:16<1:32:53, 28.58s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  38%|███▊      | 121/315 [1:06:43<1:30:19, 27.94s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  39%|███▊      | 122/315 [1:07:05<1:24:45, 26.35s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  39%|███▉      | 123/315 [1:07:27<1:19:39, 24.89s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  39%|███▉      | 124/315 [1:07:52<1:19:21, 24.93s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  40%|███▉      | 125/315 [1:08:26<1:27:45, 27.71s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  40%|████      | 126/315 [1:08:47<1:20:22, 25.51s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  40%|████      | 127/315 [1:09:33<1:39:54, 31.89s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  41%|████      | 128/315 [1:10:14<1:47:23, 34.45s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  41%|████      | 129/315 [1:11:05<2:02:48, 39.61s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  41%|████▏     | 130/315 [1:11:40<1:57:38, 38.15s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  42%|████▏     | 131/315 [1:12:15<1:53:41, 37.07s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  42%|████▏     | 132/315 [1:13:05<2:05:11, 41.05s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  42%|████▏     | 133/315 [1:13:40<1:59:23, 39.36s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  43%|████▎     | 134/315 [1:14:26<2:04:28, 41.26s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  43%|████▎     | 135/315 [1:14:52<1:50:12, 36.74s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  43%|████▎     | 136/315 [1:15:30<1:50:46, 37.13s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  43%|████▎     | 137/315 [1:15:43<1:28:48, 29.93s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  44%|████▍     | 138/315 [1:16:29<1:41:49, 34.52s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  44%|████▍     | 139/315 [1:16:44<1:24:14, 28.72s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  44%|████▍     | 140/315 [1:17:04<1:16:01, 26.07s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  45%|████▍     | 141/315 [1:17:31<1:16:36, 26.42s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  45%|████▌     | 142/315 [1:18:05<1:22:40, 28.67s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  45%|████▌     | 143/315 [1:18:32<1:20:55, 28.23s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ...
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  85%|████████▌ | 268/315 [2:21:09<20:10, 25.75s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  85%|████████▌ | 269/315 [2:21:45<21:59, 28.68s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  86%|████████▌ | 270/315 [2:21:58<18:02, 24.05s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  86%|████████▌ | 271/315 [2:22:42<22:01, 30.04s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  86%|████████▋ | 272/315 [2:23:19<22:59, 32.08s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  87%|████████▋ | 273/315 [2:24:10<26:21, 37.66s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  87%|████████▋ | 274/315 [2:24:53<26:53, 39.36s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  87%|████████▋ | 275/315 [2:25:01<20:01, 30.03s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  88%|████████▊ | 276/315 [2:25:59<24:56, 38.37s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  88%|████████▊ | 277/315 [2:26:26<22:07, 34.94s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  88%|████████▊ | 278/315 [2:26:49<19:20, 31.36s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  89%|████████▊ | 279/315 [2:27:14<17:47, 29.64s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  89%|████████▉ | 280/315 [2:27:47<17:44, 30.41s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  89%|████████▉ | 281/315 [2:28:06<15:16, 26.97s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  90%|████████▉ | 282/315 [2:28:19<12:37, 22.96s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  90%|████████▉ | 283/315 [2:28:24<09:15, 17.36s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  90%|█████████ | 284/315 [2:28:47<09:55, 19.20s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  90%|█████████ | 285/315 [2:29:03<09:07, 18.25s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  91%|█████████ | 286/315 [2:29:50<12:58, 26.84s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  91%|█████████ | 287/315 [2:30:29<14:14, 30.52s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  91%|█████████▏| 288/315 [2:31:08<14:48, 32.92s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  92%|█████████▏| 289/315 [2:31:37<13:48, 31.85s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  92%|█████████▏| 290/315 [2:32:34<16:29, 39.56s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  92%|█████████▏| 291/315 [2:33:07<15:02, 37.58s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  93%|█████████▎| 292/315 [2:33:45<14:26, 37.66s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  93%|█████████▎| 293/315 [2:34:24<13:55, 37.96s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  93%|█████████▎| 294/315 [2:34:29<09:51, 28.19s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  94%|█████████▎| 295/315 [2:34:54<09:04, 27.22s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  94%|█████████▍| 296/315 [2:35:25<08:57, 28.31s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  94%|█████████▍| 297/315 [2:35:48<07:58, 26.59s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  95%|█████████▍| 298/315 [2:36:21<08:07, 28.65s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  95%|█████████▍| 299/315 [2:36:44<07:11, 26.97s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  95%|█████████▌| 300/315 [2:36:57<05:40, 22.70s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  96%|█████████▌| 301/315 [2:37:29<05:56, 25.46s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  96%|█████████▌| 302/315 [2:38:06<06:17, 29.02s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  96%|█████████▌| 303/315 [2:38:20<04:53, 24.45s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  97%|█████████▋| 304/315 [2:39:07<05:43, 31.20s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  97%|█████████▋| 305/315 [2:39:37<05:09, 30.99s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  97%|█████████▋| 306/315 [2:40:09<04:39, 31.04s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  97%|█████████▋| 307/315 [2:40:44<04:18, 32.25s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  98%|█████████▊| 308/315 [2:41:04<03:21, 28.82s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  98%|█████████▊| 309/315 [2:41:24<02:37, 26.18s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  98%|█████████▊| 310/315 [2:41:59<02:23, 28.80s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  99%|█████████▊| 311/315 [2:42:22<01:47, 26.99s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  99%|█████████▉| 312/315 [2:43:09<01:38, 32.95s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  99%|█████████▉| 313/315 [2:43:33<01:00, 30.23s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
# 100%|█████████▉| 314/315 [2:44:09<00:31, 31.96s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
# 100%|██████████| 315/315 [2:44:25<00:00, 31.32s/it]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(true_labels, predicted_labels, classes, save_path="confusion_matrix.png"):
    """
    Plots a confusion matrix using seaborn.

    Parameters:
        true_labels (list): List of true labels
        predicted_labels (list): List of predicted labels by the model
        classes (list): List of class names
        save_path (str): Path where the plot will be saved
    """
    # Get the unique class names
    # classes = list(set(predicted_labels))

    # Compute confusion matrix and normalize it
    cm = confusion_matrix(true_labels, predicted_labels, labels=classes, normalize='true')
    cm_df = pd.DataFrame(cm, index=classes, columns=classes)

    # Plot the heatmap
    plt.figure(figsize=(15, 10))
    sns.heatmap(cm_df, annot=True, fmt=".2f", annot_kws={"size": 10}, cmap='YlGnBu')
    plt.title("Confusion Matrix")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
    # Save the figure in high quality
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    plt.show()

classes = data_melanoma_final['celltype'].unique()

# Plot and save the confusion matrix
plot_confusion_matrix(all_true, all_pred, classes, "/juno/work/shah/users/ibrahih3/codebase/space-gm/confusion_matrix_concat.png")

# %%
np.mean(all_accuracies)
# Out:
# 0.9060026014743702

# %% [markdown]
# First, we'll use a GAE to get embedings of the cells that take into account neighborhood biomarker information

# %%
import torch_geometric.utils as utils

data = utils.from_networkx(graph)

# Convert list of features to a PyTorch tensor
features_tensor = torch.tensor(data.features, dtype=torch.float)

# Add the features tensor to the Data object as the 'x' attribute
data.x = features_tensor


from torch_geometric.nn import GCNConv, GAE

class Encoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Encoder, self).__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels, cached=True)
        self.conv2 = GCNConv(2 * out_channels, out_channels, cached=True)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        return self.conv2(x, edge_index)

out_channels = 16
encoder = Encoder(data.num_features, out_channels)
model = GAE(encoder)

# Define the optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# Define the training loop
def train():
    model.train()
    optimizer.zero_grad()
    z = model.encode(data.x, data.edge_index)
    loss = model.recon_loss(z, data.edge_index)
    loss.backward()
    optimizer.step()
    return loss

for epoch in range(400):
    loss = train()
    if epoch % 10 == 0:
        print(f"Epoch: {epoch}, Loss: {loss.item()}")


embeddings = model.encode(data.x, data.edge_index)
# Out:
# /tmp/ipykernel_54039/1205688593.py:6: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   features_tensor = torch.tensor(data.features, dtype=torch.float)
# Epoch: 0, Loss: 34.538787841796875
# Epoch: 10, Loss: 34.538787841796875
# Epoch: 20, Loss: 34.538787841796875
# Epoch: 30, Loss: 34.538787841796875
# Epoch: 40, Loss: 34.538787841796875
# Epoch: 50, Loss: 34.538787841796875
# Epoch: 60, Loss: 34.538787841796875
# Epoch: 70, Loss: 34.538787841796875
# Epoch: 80, Loss: 34.538787841796875
# Epoch: 90, Loss: 34.538787841796875
# Epoch: 100, Loss: 34.538787841796875
# Epoch: 110, Loss: 34.538787841796875
# Epoch: 120, Loss: 34.538787841796875
# Epoch: 130, Loss: 34.538787841796875
# Epoch: 140, Loss: 34.538787841796875
# Epoch: 150, Loss: 34.538787841796875
# Epoch: 160, Loss: 34.538787841796875
# Epoch: 170, Loss: 34.538787841796875
# Epoch: 180, Loss: 34.538787841796875
# Epoch: 190, Loss: 34.538787841796875
# Epoch: 200, Loss: 34.538787841796875
# Epoch: 210, Loss: 34.538787841796875
# Epoch: 220, Loss: 34.538787841796875
# Epoch: 230, Loss: 34.538787841796875
# Epoch: 240, Loss: 34.538787841796875
# Epoch: 250, Loss: 34.538787841796875
# Epoch: 260, Loss: 34.538787841796875
# Epoch: 270, Loss: 34.538787841796875
# Epoch: 280, Loss: 34.538787841796875
# Epoch: 290, Loss: 34.538787841796875
# Epoch: 300, Loss: 34.538787841796875
# Epoch: 310, Loss: 34.538787841796875
# Epoch: 320, Loss: 34.538787841796875
# Epoch: 330, Loss: 34.538787841796875
# Epoch: 340, Loss: 34.538787841796875
# Epoch: 350, Loss: 34.538787841796875
# Epoch: 360, Loss: 34.538787841796875
# Epoch: 370, Loss: 34.538787841796875
# Epoch: 380, Loss: 34.538787841796875
# Epoch: 390, Loss: 34.538787841796875

# %% [markdown]
# For each cell we now have 16 features that take into account neighborhood biomarker information

# %%
embeddings.shape
# Out:
# torch.Size([4783, 16])

# %% [markdown]
# We can now use these embeddings that incorporate neighborhood information in cell prediction

# %%
# def get_train_test_dataloaders(data, X=None):
#     """
#     Convert the data into PyTorch tensors and split into training and test sets. We then return the PyTorch dataloader objects.
    
#     Parameters:
#         data (polars Dataframe): the data to be used for training and testing
#     """
    
#     # define the data loader
#     from torch.utils.data import TensorDataset, DataLoader
#     from sklearn.preprocessing import LabelEncoder

#     biomarkers = ['CD45', 'CD3', 'CD4', 'CD8', 'FOXP3', 'CD56', 'CD20', 'CD14', 'CD163', 'CD68', 
#               'SOX10', 'S100B', 'KI67', 'CD25', 'PD1', 'LAG3', 'TIM3', 'CD27', 'PDL1', 'B7H3', 
#               'IDO1', 'B2M', 'MHCI', 'MHCII', 'MRC1', 'TGM2']
    
    
#     X = data[biomarkers].to_pandas().values if X is None else X

#     # convert the biomarker data into PyTorch tensors
#     X_tensor = torch.tensor(X, dtype=torch.float)


#     # convert the cell type labels into integers
#     label_encoder = LabelEncoder()
#     cell_type_column = 'CLUSTER_LABEL' if 'CLUSTER_LABEL' in data.columns else 'celltype'
#     y = label_encoder.fit_transform(data[cell_type_column].to_pandas())  # convert to pandas for label encoding

#     # convert the labels into PyTorch tensors
#     y_tensor = torch.tensor(y, dtype=torch.long)

#     # Combine the tensors
#     dataset = TensorDataset(X_tensor, y_tensor)


#     # Split the data into training and test sets
#     train_size = int(0.8 * len(dataset))  # 80% for training
#     test_size = len(dataset) - train_size
#     train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

#     # Define your dataloaders
#     batch_size = 32  # choose the batch size that suits your needs
#     train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#     test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
    
#     return train_dataloader, test_dataloader

# %%
import polars as pl
cell_types = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_cell_types.csv")
expressions = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_expression.csv")

# join cell types and expression on CELL_ID

data = cell_types.join(expressions, on="CELL_ID")
data.head()
# Out:
# shape: (5, 29)
# ┌────────────┬────────────┬────────────┬──────────┬───┬─────────┬───────────┬───────────┬──────────┐
# │ CELL_ID    ┆ CLUSTER_LA ┆ ACQUISITIO ┆ CD45     ┆ … ┆ MHCI    ┆ MHCII     ┆ MRC1      ┆ TGM2     │
# │ ---        ┆ BEL        ┆ N_ID       ┆ ---      ┆   ┆ ---     ┆ ---       ┆ ---       ┆ ---      │
# │ str        ┆ ---        ┆ ---        ┆ f64      ┆   ┆ f64     ┆ f64       ┆ f64       ┆ f64      │
# │            ┆ str        ┆ str        ┆          ┆   ┆         ┆           ┆           ┆          │
# ╞════════════╪════════════╪════════════╪══════════╪═══╪═════════╪═══════════╪═══════════╪══════════╡
# │ 000833cf8d ┆ Tconv8     ┆ df_0_1_1   ┆ 3.554053 ┆ … ┆ 99.3433 ┆ 27.750005 ┆ 13.749991 ┆ 0.378378 │
# │ 5424a3     ┆            ┆            ┆          ┆   ┆         ┆           ┆           ┆          │
# │ 002287d8a5 ┆ Tumor      ┆ df_0_1_1   ┆ 0.0      ┆ … ┆ 64.2048 ┆ 0.011321  ┆ 6.358492  ┆ 0.086792 │
# │ 7a5200     ┆            ┆            ┆          ┆   ┆         ┆           ┆           ┆          │
# │ 00295b12f4 ┆ Adipo_Lang ┆ df_0_1_1   ┆ 0.0      ┆ … ┆ 28.9911 ┆ 0.054348  ┆ 4.875     ┆ 0.054348 │
# │ ecf52c     ┆            ┆            ┆          ┆   ┆         ┆           ┆           ┆          │
# │ 0030dccd41 ┆ Tumor      ┆ df_0_1_1   ┆ 0.0      ┆ … ┆ 37.6857 ┆ 0.0       ┆ 4.681816  ┆ 0.045455 │
# │ cea232     ┆            ┆            ┆          ┆   ┆         ┆           ┆           ┆          │
# │ 003e872c63 ┆ Tumor      ┆ df_0_1_1   ┆ 0.0      ┆ … ┆ 49.2222 ┆ 5.337835  ┆ 7.489865  ┆ 0.435811 │
# │ 78b64d     ┆            ┆            ┆          ┆   ┆         ┆           ┆           ┆          │
# └────────────┴────────────┴────────────┴──────────┴───┴─────────┴───────────┴───────────┴──────────┘

# %%
cell_types = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_cell_types.csv")
expressions = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_expression.csv")

# join cell types and expression on CELL_ID

data = cell_types.join(expressions, on="CELL_ID")

# Define the model

input_size = 16
hidden_size = 50  # could be optimized
num_classes = len(data["CLUSTER_LABEL"].unique())

# create the model and transfer it to GPU if avilable
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
model = CellClassifier(input_size, hidden_size, num_classes).to(device)

# get the train and test dataloaders
train_dataloader, test_dataloader = get_train_test_dataloaders(data, embeddings) # Here, X is the embeddings we got from the GAE


train_model(model, train_dataloader, num_epochs=200)
_, _ = test_model(model, test_dataloader)
# Out:
# /tmp/ipykernel_54039/397157535.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
# Epoch 0 Loss 1.0922988653182983
# Epoch 10 Loss 1.6689486503601074
# Epoch 20 Loss 0.8977508544921875
# Epoch 30 Loss 1.1760469675064087
# Epoch 40 Loss 1.3825315237045288
# Epoch 50 Loss 1.30229914188385
# Epoch 60 Loss 1.149011254310608
# Epoch 70 Loss 1.3214633464813232
# Epoch 80 Loss 0.7705710530281067
# Epoch 90 Loss 1.0232899188995361
# Epoch 100 Loss 1.2888140678405762
# Epoch 110 Loss 0.9777909517288208
# Epoch 120 Loss 1.0086543560028076
# Epoch 130 Loss 1.7757019996643066
# Epoch 140 Loss 0.6779967546463013
# Epoch 150 Loss 1.2373236417770386
# Epoch 160 Loss 0.985382080078125
# Epoch 170 Loss 1.124851942062378
# Epoch 180 Loss 0.6361610889434814
# Epoch 190 Loss 0.46576112508773804
# Test Accuracy: 60.19 %

# %% [markdown]
# ### Next, we can use simple concatenation of biomarkers from the neighbors of a cell. We will use diffrent aggregation methods (mean, sum, and max) and concatenate that with the original node's embeddinembedding. We then use this to make the predictions (Mean, sum, max)

# %%
# use concatenation of embeddings to predict cell type

import torch_geometric.utils as utils

def get_new_embedding(data, G, aggr='mean'):
    """
    Concatenate the embeddings of the nodes in the graph to get a new embedding
    
    Args:
        data (torch_geometric.data.Data): the data object containing the node features
        G (networkx.classes.graph.Graph): the graph used to get the neighbors of each node
        aggr (str): the aggregation method to use for the neighbors' embeddings. Can be 'mean', 'sum', or 'max'
        
    Returns:
        new_embeddings (list): a list of the new embeddings for each node in the graph
    """
    
    neighbors_dict = {node: list(neighbors.keys()) for node, neighbors in G.adjacency()}  # get all the neighbors of the current node
    new_embeddings = []
    
    for node in neighbors_dict:
        node_embedding = data.x[node]
        neighbors = neighbors_dict[node][1:]  # remove the current node from the neighbors
        neighbor_embeddings = data.x[neighbors]          
        
        if len(neighbor_embeddings) > 0:
            if aggr == 'mean':
                neighbor_embeddings_aggregated = torch.mean(neighbor_embeddings, dim=0)
            elif aggr == 'sum':
                neighbor_embeddings_aggregated = torch.sum(neighbor_embeddings, dim=0)
            elif aggr == 'max':
                neighbor_embeddings_aggregated = torch.max(neighbor_embeddings, dim=0)[0]
        else:
            # Handle the case where a node has no neighbors
            # Adjust the dimensions as necessary
            neighbor_embeddings_aggregated = torch.zeros_like(data.x[node])
                
        new_embedding = torch.cat((node_embedding, neighbor_embeddings_aggregated), dim=0)
        new_embeddings.append(new_embedding)
        
    # return a tensor object of the new embeddings
    return torch.stack(new_embeddings)

# Read in the data
coordinates_with_id = pd.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_coords.csv")
expressions_with_id = pd.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_expression.csv")

cell_types = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_cell_types.csv")
expressions = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_expression.csv")

# join cell types and expression on CELL_ID

data = cell_types.join(expressions, on="CELL_ID")

coordinates = coordinates_with_id[['X', 'Y']]

graph = create_graph_from_coordinates(coordinates, 30, expressions_with_id)
G = utils.from_networkx(graph)

# Convert list of features to a PyTorch tensor
G.features = np.array(G.features).astype(float)
features_tensor = torch.tensor(G.features, dtype=torch.float)

# Add the features tensor to the Data object as the 'x' attribute
G.x = features_tensor

# get the new embeddings

new_embeddings_mean = get_new_embedding(G, graph, aggr='mean')
new_embeddings_sum = get_new_embedding(G, graph, aggr='sum')
new_embeddings_max = get_new_embedding(G, graph, aggr='max')

# %% [markdown]
# Here, we can see that the shape of the embeddings that we get by concatenating the features of a node with the features of its neighbors using different aggregation methods is (num_of_cells, 52). The 52 is because we are doubling the features due to concatenation

# %%
new_embeddings_mean.shape
# Out:
# torch.Size([4783, 52])

# %% [markdown]
# Now, we are going to train the neural network we have been using so far to predict cell types. We'll be using the new embeddings we got by concatenating the features of a cell with its neighbors

# %%
# Define the model

input_size = 52  # 26 from the cell itself and 26 aggregated from the neighbors
hidden_size = 50 # could be optimized
num_classes = 16 # we have 16 cell types (including the 'Unknown')

# create the model and transfer it to GPU if avilable
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
model = CellClassifier(input_size, hidden_size, num_classes).to(device)

# %%
# get the train and test dataloaders for the embeddings using mean
model = CellClassifier(input_size, hidden_size, num_classes).to(device)
train_dataloader, test_dataloader = get_train_test_dataloaders(data, new_embeddings_mean) # Here, X is the embeddings we got from concatenation using mean aggregation

train_model(model, train_dataloader, num_epochs=200)
_, _ = test_model(model, test_dataloader)
# Out:
# /tmp/ipykernel_27977/3101106786.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
# Epoch 0 Loss 0.4987093508243561
# Epoch 10 Loss 0.5108866095542908
# Epoch 20 Loss 0.2794076204299927
# Epoch 30 Loss 0.6041281819343567
# Epoch 40 Loss 0.248414546251297
# Epoch 50 Loss 0.2857617139816284
# Epoch 60 Loss 0.11804752796888351
# Epoch 70 Loss 0.047359928488731384
# Epoch 80 Loss 0.22497336566448212
# Epoch 90 Loss 0.30577418208122253
# Epoch 100 Loss 0.4637693166732788
# Epoch 110 Loss 0.47099795937538147
# Epoch 120 Loss 0.07304821908473969
# Epoch 130 Loss 0.07785359025001526
# Epoch 140 Loss 0.3100198209285736
# Epoch 150 Loss 0.09447690844535828
# Epoch 160 Loss 0.07366372644901276
# Epoch 170 Loss 0.021874848753213882
# Epoch 180 Loss 0.0884237065911293
# Epoch 190 Loss 0.08001233637332916
# Test Accuracy: 88.40 %

# %% [markdown]
# ### Try mean aggregation after removing 'Unknown' cell types

# %%
# Read in the data
coordinates_with_id = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_coords.csv")
expressions_with_id = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_expression.csv")

cell_types = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_cell_types.csv")
expressions = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_expression.csv")

data = cell_types.join(expressions, on="CELL_ID")

# get unique cluster labels and their counts

cell_types_counts = data.groupby("CLUSTER_LABEL").count()

# remove 'Unknown' cluster label from the data

data_without_unknown = data.filter(pl.col("CLUSTER_LABEL") != "Unknown")

coordinates_with_id_without_unknown = coordinates_with_id.filter(pl.col("CELL_ID").is_in(data_without_unknown["CELL_ID"]))

coordinates = coordinates_with_id_without_unknown[['X', 'Y']].to_pandas()

expressions_with_id = expressions_with_id.filter(pl.col("CELL_ID").is_in(data_without_unknown["CELL_ID"])).to_pandas()

graph = create_graph_from_coordinates(coordinates, 30, expressions_with_id)
G = utils.from_networkx(graph)

# Convert list of features to a PyTorch tensor
G.features = np.array(G.features).astype(float)
features_tensor = torch.tensor(G.features, dtype=torch.float)

# Add the features tensor to the Data object as the 'x' attribute
G.x = features_tensor

# get the new embeddings

new_embeddings_mean_without_unknown = get_new_embedding(G, graph, aggr='mean')
# new_embeddings_sum = get_new_embedding(G, graph, aggr='sum')
# new_embeddings_max = get_new_embedding(G, graph, aggr='max')

# %%
new_embeddings_mean_without_unknown.shape
# Out:
# torch.Size([4045, 52])

# %%
# Define the model

input_size = 52  # 26 from the cell itself and 26 aggregated from the neighbors
hidden_size = 50 # could be optimized
num_classes = 15 # we have 15 cell types because we removed 'Unknown'

# create the model and transfer it to GPU if avilable
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
model = CellClassifier(input_size, hidden_size, num_classes).to(device)


# get the train and test dataloaders for the embeddings using mean
model = CellClassifier(input_size, hidden_size, num_classes).to(device)
train_dataloader, test_dataloader = get_train_test_dataloaders(data_without_unknown, new_embeddings_mean_without_unknown) # Here, X is the embeddings we got from concatenation using mean aggregation (unknowns removed)

train_model(model, train_dataloader, num_epochs=200)
_, _ = test_model(model, test_dataloader)
# Out:
# /tmp/ipykernel_27977/3101106786.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
# Epoch 0 Loss 0.7684526443481445
# Epoch 10 Loss 0.16881528496742249
# Epoch 20 Loss 0.17929576337337494
# Epoch 30 Loss 0.22477661073207855
# Epoch 40 Loss 0.00548475282266736
# Epoch 50 Loss 0.09489375352859497
# Epoch 60 Loss 0.12243250012397766
# Epoch 70 Loss 0.0009785911533981562
# Epoch 80 Loss 0.04413973167538643
# Epoch 90 Loss 0.16522681713104248
# Epoch 100 Loss 0.002970104804262519
# Epoch 110 Loss 6.347855560306925e-06
# Epoch 120 Loss 0.05253315716981888
# Epoch 130 Loss 0.1686050444841385
# Epoch 140 Loss 0.037947457283735275
# Epoch 150 Loss 0.00022811545932199806
# Epoch 160 Loss 0.0016007040394470096
# Epoch 170 Loss 6.0585462051676586e-05
# Epoch 180 Loss 0.0005245094653218985
# Epoch 190 Loss 8.626403723610565e-05
# Test Accuracy: 94.56 %

# %% [markdown]
# ### Using K-fold cross validation for aggregation by mean

# %%
# import polars as pl


# cell_types = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_cell_types.csv")
# expressions = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_expression.csv")

# # join cell types and expression on CELL_ID

# data = cell_types.join(expressions, on="CELL_ID")

# from sklearn.preprocessing import LabelEncoder
# from torch.utils.data import TensorDataset

# # List of biomarkers
# biomarkers = ['CD45', 'CD3', 'CD4', 'CD8', 'FOXP3', 'CD56', 'CD20', 'CD14', 'CD163', 'CD68', 
#               'SOX10', 'S100B', 'KI67', 'CD25', 'PD1', 'LAG3', 'TIM3', 'CD27', 'PDL1', 'B7H3', 
#               'IDO1', 'B2M', 'MHCI', 'MHCII', 'MRC1', 'TGM2']

# Extract biomarker data and convert to tensor
X = new_embeddings_mean_without_unknown
X_tensor = torch.tensor(X, dtype=torch.float)

# Convert cell type labels into integers and then to tensor
label_encoder = LabelEncoder()
cell_type_column = 'CLUSTER_LABEL' if 'CLUSTER_LABEL' in data_without_unknown.columns else 'celltype'
y = label_encoder.fit_transform(data_without_unknown[cell_type_column].to_pandas())
y_tensor = torch.tensor(y, dtype=torch.long)

input_size = 52  # 26 from the cell itself and 26 aggregated from the neighbors
hidden_size = 50 # could be optimized
num_classes = 16 # we have 16 cell types

# create the model and transfer it to GPU if avilable
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
model = CellClassifier(input_size, hidden_size, num_classes).to(device)

dataset = TensorDataset(X_tensor, y_tensor)
accuracies = train_test_model_k_fold(dataset, input_size=52, hidden_size=50, num_classes=15, k=5, num_epochs=200)
# Out:
# /tmp/ipykernel_4231/4257429549.py:21: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
# FOLD 0
# --------------------------------
# Epoch 0 Loss 1.2988338470458984
# Epoch 10 Loss 0.03283959999680519
# Epoch 20 Loss 0.020473597571253777
# Epoch 30 Loss 0.01485095452517271
# Epoch 40 Loss 0.04047683998942375
# Epoch 50 Loss 0.29759839177131653
# Epoch 60 Loss 0.013387695886194706
# Epoch 70 Loss 0.000847030256409198
# Epoch 80 Loss 0.022058501839637756
# Epoch 90 Loss 0.02668997459113598
# Epoch 100 Loss 0.00011823157547041774
# Epoch 110 Loss 1.3161166906356812
# Epoch 120 Loss 9.99089315882884e-05
# Epoch 130 Loss 0.00012304828851483762
# Epoch 140 Loss 1.2079436601197813e-05
# Epoch 150 Loss 0.09505071491003036
# Epoch 160 Loss 0.019540172070264816
# Epoch 170 Loss 5.940491519140778e-06
# Epoch 180 Loss 0.0003763295244425535
# Epoch 190 Loss 7.679387636017054e-05
# Accuracy for fold 0: 94.56118665018542%
# FOLD 1
# --------------------------------
# Epoch 0 Loss 0.4148170053958893
# Epoch 10 Loss 0.13623015582561493
# Epoch 20 Loss 0.3431856632232666
# Epoch 30 Loss 0.3568863868713379
# Epoch 40 Loss 0.6613098382949829
# Epoch 50 Loss 0.03760446980595589
# Epoch 60 Loss 0.002147241262719035
# Epoch 70 Loss 0.0002743577060755342
# Epoch 80 Loss 0.0006161388591863215
# Epoch 90 Loss 0.06307803839445114
# Epoch 100 Loss 0.0013946451945230365
# Epoch 110 Loss 0.06610862165689468
# Epoch 120 Loss 0.00012114469427615404
# Epoch 130 Loss 0.002019466133788228
# Epoch 140 Loss 8.810393046587706e-05
# Epoch 150 Loss 0.002774101449176669
# Epoch 160 Loss 0.0006403814186342061
# Epoch 170 Loss 0.000492586346808821
# Epoch 180 Loss 0.04552054405212402
# Epoch 190 Loss 0.008797569200396538
# Accuracy for fold 1: 93.57231149567366%
# FOLD 2
# --------------------------------
# Epoch 0 Loss 0.007295152172446251
# Epoch 10 Loss 0.2426835149526596
# Epoch 20 Loss 0.002194916130974889
# Epoch 30 Loss 0.16681675612926483
# Epoch 40 Loss 0.19614249467849731
# Epoch 50 Loss 0.0006855514948256314
# Epoch 60 Loss 0.0010659421095624566
# Epoch 70 Loss 0.09217893332242966
# Epoch 80 Loss 0.0032246820628643036
# Epoch 90 Loss 0.06647428125143051
# Epoch 100 Loss 0.293879896402359
# Epoch 110 Loss 0.008504838682711124
# Epoch 120 Loss 0.009636473841965199
# Epoch 130 Loss 2.938258148788009e-05
# Epoch 140 Loss 7.627919694641605e-05
# Epoch 150 Loss 0.012386518530547619
# Epoch 160 Loss 0.008633807301521301
# Epoch 170 Loss 5.4391202866099775e-05
# Epoch 180 Loss 0.00022541168436873704
# Epoch 190 Loss 0.00019566946139093488
# Accuracy for fold 2: 93.57231149567366%
# FOLD 3
# --------------------------------
# Epoch 0 Loss 0.8692011833190918
# Epoch 10 Loss 0.2425098866224289
# Epoch 20 Loss 0.25688374042510986
# Epoch 30 Loss 0.2912197411060333
# Epoch 40 Loss 0.24863503873348236
# Epoch 50 Loss 0.021958040073513985
# Epoch 60 Loss 0.0089108319953084
# Epoch 70 Loss 0.0004872916906606406
# Epoch 80 Loss 0.025508567690849304
# Epoch 90 Loss 0.03532939404249191
# Epoch 100 Loss 2.3503229385823943e-05
# Epoch 110 Loss 4.748437277157791e-06
# Epoch 120 Loss 0.0012194247683510184
# Epoch 130 Loss 0.03716019168496132
# Epoch 140 Loss 0.4510843753814697
# Epoch 150 Loss 0.0014527983730658889
# Epoch 160 Loss 0.001296436763368547
# Epoch 170 Loss 6.622815999435261e-05
# Epoch 180 Loss 0.23840922117233276
# Epoch 190 Loss 0.00015434705710504204
# Accuracy for fold 3: 92.95426452410383%
# FOLD 4
# --------------------------------
# Epoch 0 Loss 0.4778093099594116
# Epoch 10 Loss 0.6354294419288635
# Epoch 20 Loss 0.2884623110294342
# Epoch 30 Loss 0.3404034376144409
# Epoch 40 Loss 1.8772236108779907
# Epoch 50 Loss 0.1620226949453354
# Epoch 60 Loss 0.0026605406310409307
# Epoch 70 Loss 0.03669511154294014
# Epoch 80 Loss 0.09882839769124985
# Epoch 90 Loss 0.11464642733335495
# Epoch 100 Loss 0.5183221697807312
# Epoch 110 Loss 2.7815488579108205e-07
# Epoch 120 Loss 0.004180313553661108
# Epoch 130 Loss 0.003038657596334815
# Epoch 140 Loss 0.0013498381013050675
# Epoch 150 Loss 2.4835142085066764e-06
# Epoch 160 Loss 0.26213234663009644
# Epoch 170 Loss 0.005643206182867289
# Epoch 180 Loss 0.0015699107898399234
# Epoch 190 Loss 0.00920004304498434
# Accuracy for fold 4: 94.93201483312733%
# --------------------------------
# FINAL RESULTS
# Average accuracy across 5-folds: 93.91841779975279%
# --------------------------------

# %%
# get the train and test dataloaders for the embeddings using sum
model = CellClassifier(input_size, hidden_size, num_classes).to(device)
train_dataloader, test_dataloader = get_train_test_dataloaders(data, new_embeddings_sum) # Here, X is the embeddings we got from concatenation using sum aggregation

train_model(model, train_dataloader, num_epochs=200)
_, _ = test_model(model, test_dataloader)
# Out:
# /tmp/ipykernel_65848/397157535.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
# Epoch 0 Loss 2.2566192150115967
# Epoch 10 Loss 1.614545226097107
# Epoch 20 Loss 1.41700279712677
# Epoch 30 Loss 2.435934066772461
# Epoch 40 Loss 1.650402545928955
# Epoch 50 Loss 1.4668395519256592
# Epoch 60 Loss 1.4829169511795044
# Epoch 70 Loss 1.3119492530822754
# Epoch 80 Loss 1.4111711978912354
# Epoch 90 Loss 1.024487018585205
# Epoch 100 Loss 1.173991084098816
# Epoch 110 Loss 1.1464533805847168
# Epoch 120 Loss 1.6214889287948608
# Epoch 130 Loss 1.2997307777404785
# Epoch 140 Loss 0.9659758806228638
# Epoch 150 Loss 1.0256459712982178
# Epoch 160 Loss 0.96315598487854
# Epoch 170 Loss 1.1570290327072144
# Epoch 180 Loss 1.2170237302780151
# Epoch 190 Loss 1.4750899076461792
# Test Accuracy: 63.22 %

# %%
# get the train and test dataloaders for the embeddings using max
model = CellClassifier(input_size, hidden_size, num_classes).to(device)
train_dataloader, test_dataloader = get_train_test_dataloaders(data, new_embeddings_max) # Here, X is the embeddings we got from concatenation using max aggregation

train_model(model, train_dataloader)
_, _ = test_model(model, test_dataloader)
# Out:
# /tmp/ipykernel_65848/397157535.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
# Epoch 0 Loss 1.234483242034912
# Epoch 10 Loss 0.36071425676345825
# Epoch 20 Loss 0.4061279892921448
# Epoch 30 Loss 0.2954835593700409
# Epoch 40 Loss 0.30058467388153076
# Epoch 50 Loss 0.2682393789291382
# Epoch 60 Loss 0.18293879926204681
# Epoch 70 Loss 0.04012836515903473
# Epoch 80 Loss 0.2759762406349182
# Epoch 90 Loss 0.12009065598249435
# Test Accuracy: 84.64 %

# %% [markdown]
# ### Try out different thresholds

# %%
# Read in the data
coordinates_with_id = pd.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_coords.csv")
expressions_with_id = pd.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_expression.csv")

cell_types = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_cell_types.csv")
expressions = pl.read_csv("/juno/work/shah/users/ibrahih3/codebase/space-gm/data_melanoma/df_0_1_1_expression.csv")

# join cell types and expression on CELL_ID

data = cell_types.join(expressions, on="CELL_ID")

coordinates = coordinates_with_id[['X', 'Y']]

threshold_space = range(5,100,5)
accuracy_for_different_thresholds = []

for threshold in tqdm(threshold_space):

    graph = create_graph_from_coordinates(coordinates, threshold, expressions_with_id)
    G = utils.from_networkx(graph)

    # Convert list of features to a PyTorch tensor
    G.features = np.array(G.features).astype(float)
    features_tensor = torch.tensor(G.features, dtype=torch.float)

    # Add the features tensor to the Data object as the 'x' attribute
    G.x = features_tensor

    # get the new embeddings
    new_embeddings_mean = get_new_embedding(G, graph, aggr='mean')
    # new_embeddings_sum = get_new_embedding(G, graph, aggr='sum')
    # new_embeddings_max = get_new_embedding(G, graph, aggr='max')
    
    # Define the model

    input_size = 52  # 26 from the cell itself and 26 aggregated from the neighbors
    hidden_size = 50 # could be optimized
    num_classes = 16 # we have 16 cell types (including the 'Unknown')

    # create the model and transfer it to GPU if avilable
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    model = CellClassifier(input_size, hidden_size, num_classes).to(device)
    
    # get the train and test dataloaders for the embeddings using mean
    model = CellClassifier(input_size, hidden_size, num_classes).to(device)
    train_dataloader, test_dataloader = get_train_test_dataloaders(data, new_embeddings_mean) # Here, X is the embeddings we got from concatenation using mean aggregation

    train_model(model, train_dataloader, num_epochs=100, print_loss=False)
    accuracy = test_model_thresholds(model, test_dataloader)
    
    # print(f'Accuracy for threshold {threshold} = {accuracy}')
    
    accuracy_for_different_thresholds.append(accuracy)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#   5%|▌         | 1/19 [00:21<06:33, 21.84s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  11%|█         | 2/19 [00:40<05:41, 20.12s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  16%|█▌        | 3/19 [01:00<05:18, 19.91s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  21%|██        | 4/19 [01:18<04:45, 19.03s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  26%|██▋       | 5/19 [01:36<04:20, 18.64s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  32%|███▏      | 6/19 [01:54<04:02, 18.66s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  37%|███▋      | 7/19 [02:15<03:50, 19.21s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  42%|████▏     | 8/19 [02:34<03:33, 19.43s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  47%|████▋     | 9/19 [02:54<03:16, 19.61s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  53%|█████▎    | 10/19 [03:14<02:56, 19.63s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  58%|█████▊    | 11/19 [03:34<02:37, 19.65s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  63%|██████▎   | 12/19 [03:54<02:19, 19.90s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  68%|██████▊   | 13/19 [04:17<02:04, 20.81s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  74%|███████▎  | 14/19 [04:38<01:43, 20.77s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  79%|███████▉  | 15/19 [04:59<01:23, 20.88s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  84%|████████▍ | 16/19 [05:22<01:04, 21.37s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  89%|████████▉ | 17/19 [05:44<00:43, 21.61s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
#  95%|█████████▍| 18/19 [06:06<00:21, 21.92s/it]/tmp/ipykernel_45911/1826913275.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, dtype=torch.float)
# 100%|██████████| 19/19 [06:30<00:00, 20.54s/it]

# %%
np.argmax(np.array(accuracy_for_different_thresholds)), accuracy_for_different_thresholds[14], list(range(5,100,5))[14]
# Out:
# (14, 0.922675026123302, 75)

# %%
import matplotlib.pyplot as plt

# Find the maximum accuracy and corresponding threshold
max_accuracy = max(accuracy_for_different_thresholds)
max_threshold = threshold_space[np.argmax(accuracy_for_different_thresholds)]

plt.figure(figsize=(10, 6))
plt.plot(threshold_space, accuracy_for_different_thresholds, marker='o')
plt.title("Model accuracy for different thresholds")
plt.xlabel("Threshold")
plt.ylabel("Accuracy")
plt.grid(True)
plt.show()

print("Maximum accuracy: ", max_accuracy)
print("Corresponding threshold: ", max_threshold)
# Out:
# Maximum accuracy:  0.9258098223615465
# Corresponding threshold:  65

# %% [markdown]
# ### Try complete GNNs (with multiple GNN layers). Try multiple types of layers

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, GATConv, GINConv

class GNN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers):
        super(GNN, self).__init__()
        self.layers = torch.nn.ModuleList()
        self.layers.append(GCNConv(input_dim, hidden_dim))
        for _ in range(num_layers - 2):  # Subtract 2 to account for the first and last layers
            self.layers.append(GCNConv(hidden_dim, hidden_dim))
        self.layers.append(GCNConv(hidden_dim, output_dim))

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        for i in range(len(self.layers) - 1):
            x = self.layers[i](x, edge_index)
            x = F.relu(x)
            x = F.dropout(x, training=self.training)

        x = self.layers[-1](x, edge_index)  # Last layer

        return F.log_softmax(x, dim=1)

# %%
def train_model(model, data, device, num_epochs=100):
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

    # Transfer to GPU
    data = data.to(device)
    model = model.to(device)

    train_mask = torch.arange(data.num_nodes) < (0.8 * data.num_nodes)  # train on the first 80% nodes

    for epoch in range(num_epochs):
        optimizer.zero_grad()
        out = model(data)
        loss = F.nll_loss(out[train_mask], data.y[train_mask])
        loss.backward()
        optimizer.step()
        if epoch % 10 == 0:
            print(f'Epoch {epoch}: Loss {loss.item()}')

def test_model(model, data, device):
    model.eval()
    _, pred = model(data).max(dim=1)

    test_mask = torch.arange(data.num_nodes) >= (0.8 * data.num_nodes)  # test on the last 20% nodes

    correct = float(pred[test_mask].eq(data.y[test_mask]).sum().item())
    acc = correct / test_mask.sum().item()

    print(f'Test Accuracy: {acc}')

    return acc


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define the model
input_dim = 26  # initial number of features
hidden_dim = 50  # number of features in hidden layers
output_dim = 15  # number of classes
num_layers = 1  # total number of layers in the network

model = GNN(input_dim, hidden_dim, output_dim, num_layers).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# Train and test the model
train_model(model, G, device, num_epochs=200)  # make sure G is a PyTorch Geometric `Data` object
test_model(model, G, device)
# Out:
# Epoch 0: Loss 34.54243850708008
# Epoch 10: Loss 3.277630090713501
# Epoch 20: Loss 1.8164186477661133
# Epoch 30: Loss 1.3946208953857422
# Epoch 40: Loss 1.1000452041625977
# Epoch 50: Loss 0.9977823495864868
# Epoch 60: Loss 0.9669572710990906
# Epoch 70: Loss 0.9075634479522705
# Epoch 80: Loss 0.8854423761367798
# Epoch 90: Loss 0.8745573163032532
# Epoch 100: Loss 0.8506774306297302
# Epoch 110: Loss 0.84134840965271
# Epoch 120: Loss 0.8339268565177917
# Epoch 130: Loss 0.8202671408653259
# Epoch 140: Loss 0.8092160224914551
# Epoch 150: Loss 0.8016700744628906
# Epoch 160: Loss 0.7936156392097473
# Epoch 170: Loss 0.7959132790565491
# Epoch 180: Loss 0.7889617085456848
# Epoch 190: Loss 0.7752376198768616
# Test Accuracy: 0.7033374536464772
# 0.7033374536464772

# %%
y = label_encoder.fit_transform(data_without_unknown[cell_type_column].to_pandas())
G.y = torch.tensor(y, dtype=torch.long)
G
# Out:
# Data(edge_index=[2, 77277], features=[4045, 26], weight=[77277], num_nodes=4045, x=[4045, 26], y=[4045])
